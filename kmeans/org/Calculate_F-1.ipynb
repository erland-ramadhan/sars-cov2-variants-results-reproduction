# %%
import numpy as np

# %%
calculated_cluster = np.load('new_no_feature_selection_Labels_kmeans.npy')

# %%
import pandas as pd

# %%
pd.DataFrame(calculated_cluster)
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 62652  0
# 62653  0
# 62654  0
# 62655  3
# 62656  0
#
# [62657 rows x 1 columns]

# %%
pd.read_csv('new_no_feature_selection_int_true_variants_k_5.csv', header=None)
# Out:
#        0
# 0      0
# 1      0
# 2      2
# 3      2
# 4      2
# ...   ..
# 62652  3
# 62653  3
# 62654  3
# 62655  4
# 62656  4
#
# [62657 rows x 1 columns]

# %%
calculated_cluster_2 = np.load('./new_no_feature_selection_Labels_kmeans_2.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/erland/OneDrive - UNIVERSITAS INDONESIA/my_study/07_komputasi_lanjut_dan_big_data/midterm/reproduce_paper-1/kmeans/org/Calculate_F-1.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/erland/OneDrive%20-%20UNIVERSITAS%20INDONESIA/my_study/07_komputasi_lanjut_dan_big_data/midterm/reproduce_paper-1/kmeans/org/Calculate_F-1.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> calculated_cluster_2 = np.load('./new_no_feature_selection_Labels_kmeans_2.npy')
#
# File ~/anaconda3/envs/err-KLBD/lib/python3.9/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# ...
